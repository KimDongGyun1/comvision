# %% [markdown]
# # 1.4.3 Geometric Transformations of Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Scaling

# %%
img = cv2.imread('sIMG_2164.jpg')
resN = cv2.resize(img,None,fx=4, fy=4, interpolation = cv2.INTER_NEAREST)
resC = cv2.resize(img,None,fx=4, fy=4, interpolation = cv2.INTER_CUBIC)

# %%
cv2.imshow('image',img)
cv2.imshow('resN image',resN)
cv2.imshow('resC image',resC)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#OR
height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)

# %%
cv2.imshow('image',img)
cv2.imshow('res image',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Translation

# %%
img = cv2.imread('sIMG_2164.jpg',1)
tx = 300
ty = 150
rows,cols,ch = img.shape
M = np.float32([[1,0,tx],[0,1,ty]])
dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.rectangle(dst,(0,0),(tx,ty),(0,255,0),-1)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Rotation

# %%
img = cv2.imread('sIMG_2164.jpg',1)
rows,cols,ch = img.shape
cx = 100
cy = 200
theta = 45
M = cv2.getRotationMatrix2D((cy,cx),theta,1)
dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.circle(dst,(cx,cy), 10, (0,0,255), -1)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Affine Transformation

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231]])
pts2 = np.float32([[235,457],[235,270],[570,270]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('simg',dst)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Perspective Transformation

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(0,0))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[579,338],[753,375],[763,543],[584,543]])
pts2 = np.float32([[579,340],[760,340],[760,540],[579,540]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
